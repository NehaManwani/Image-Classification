# %% [markdown]
# ## Data Download and Preprocessing
# Download the dataset from the provided Google Drive link.
# Implement preprocessing techniques to prepare the images for feature extraction.

# %%
import os
import cv2
import numpy as np
from sklearn.decomposition import PCA
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, accuracy_score
import pickle

# Function to load images and labels from subdirectories
def load_images_from_folder(folder):
    images = []
    labels = []

    if not os.path.exists(folder):
        print(f"Folder path '{folder}' does not exist.")
        return np.array(images), np.array(labels)

    for sub in os.listdir(folder):
        sub_path = os.path.join(folder, sub)
        if not os.path.isdir(sub_path):
            print(f"'{sub_path}' is not a directory.")
            continue
        for filename in os.listdir(sub_path):
            img_path = os.path.join(sub_path, filename)
            if not os.path.isfile(img_path):
                print(f"File '{img_path}' is not a valid file.")
                continue
            img = cv2.imread(img_path)
            if img is None:
                print(f"Failed to read image '{img_path}'.")
                continue
            img = cv2.resize(img, (128, 128))  # Resize images to 128x128
            img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
            images.append(img_gray)
            labels.append(sub)  # Use the subdirectory name as the label
            print(f"Loaded image '{img_path}' with label '{sub}'.")

    if not images:
        print(f"No images were loaded from the folder '{folder}'.")
        
    return np.array(images), np.array(labels)

# Load dataset 
images, labels = load_images_from_folder('C:\\Users\\91990\\Downloads\\dataset\\data\\dataset_full')

# Check if images and labels are loaded correctly
print(f"Number of images loaded: {len(images)}")
print(f"Number of labels loaded: {len(labels)}")
# Out:
# Failed to read image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\.DS_Store'.
# File 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\.ipynb_checkpoints' is not a valid file.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\0.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\10014.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\10144.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\10191.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\10210.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\10228.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\10251.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\10312.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\1041.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\10444.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\10480.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\10485.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\10489.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\1064.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\10641.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\10672.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\10878.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\10921.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\11054.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\11055.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\11084.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\112.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\11209.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\11302.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\11425.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\11499.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\11570.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\11605.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\1161.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\11622.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\11628.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\11910.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\1193.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\11947.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\11959.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\11961.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\1204.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\12042.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\12063.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\12067.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\12103.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\12144.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\12172.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\12233.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\12391.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\12435.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\1244.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\12533.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\12543.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\12561.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\12590.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\12617.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\12659.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\12782.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\1281.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\12818.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\12887.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\12963.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\12996.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\1303.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\13111.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\13135.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\13188.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\13236.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\13238.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\13400.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\13480.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\13511.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\13526.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\13533.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\13590.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\13640.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\13676.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\13681.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\13697.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\13741.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\13777.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\13823.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\13846.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\13951.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\13978.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\14014.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\14022.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\14217.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\14284.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\14295.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\14300.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\14372.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\14565.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\14576.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\14691.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\14708.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\14744.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\14749.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\14758.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\14856.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\14857.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\14876.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\14918.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\14952.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\14958.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\15052.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\15109.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\15140.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\15216.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\15236.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\15261.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\15288.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\15404.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\15405.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\15409.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\1542.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\15429.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\1550.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\15626.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\1569.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\15690.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\15784.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\15787.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\15794.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\158.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\15864.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\15906.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\15920.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\15938.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\15985.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\16057.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\1611.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\16123.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\16137.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\16141.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\16166.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\16221.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\16243.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\1629.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\1630.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\16314.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\16339.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\16483.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\16564.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\16567.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\16575.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\16593.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\16594.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\16595.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\16607.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\16614.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\16734.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\1683.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\16889.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\16988.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\17156.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\1718.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\17202.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\17225.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\17273.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\17296.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\17322.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\17330.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\17401.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\17403.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\17450.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\17452.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\17453.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\17516.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\17539.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\17581.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\17602.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\17605.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\1763.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\17719.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\17771.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\17830.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\17891.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\17898.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\17983.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\18087.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\18182.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\18201.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\18312.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\18324.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\18446.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\1846.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\18467.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\18542.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\18548.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\18550.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\18580.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\18639.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\18655.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\1872.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\18752.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\18756.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\18767.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\18815.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\18854.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\18875.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\18962.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\18971.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\1901.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\19217.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\19249.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\19256.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\19280.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\19302.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\19347.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\19374.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\1940.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\19446.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\19455.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\19513.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\1959.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\19623.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\19638.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\1964.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\19661.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\19666.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\19778.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\19830.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\19874.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\19973.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\20094.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\20131.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\2038.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\20465.jpg' with label 'Building'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Building\
jpg' with label 'Streets'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Streets\9926.jpg' with label 'Streets'.
# Loaded image 'C:\Users\91990\Downloads\dataset\data\dataset_full\Streets\994.jpg' with label 'Streets'.
# Number of images loaded: 5245
# Number of labels loaded: 5245

# %% [markdown]
# # Feature Extraction
#
# Extract multiple sets of handcrafted features, with at least three features per set.
# Examples of features to extract:
# Low-level Vision: Histogram, Histogram Equalization, Gray-scale Transformation, Image Smoothing, Connected Components in Images.
# Mid-level Vision: Edge Detection (using Gradients, Sobel, Canny), Line Detection (using Hough Transforms), Semantic Information (using RANSAC), Image Region Descriptors (using SIFT).

# %%
# Function to calculate histogram and flatten it
def calc_histogram(img):
    hist = cv2.calcHist([img], [0], None, [256], [0, 256])
    return hist.flatten()

# Function to detect edges using Canny and flatten the result
def canny_edge_detection(img):
    edges = cv2.Canny(img, 100, 200)
    return edges.flatten()

# Function to extract SIFT features and ensure the length is consistent
def sift_features(img, num_features=128):
    sift = cv2.SIFT_create()
    keypoints, descriptors = sift.detectAndCompute(img, None)
    if descriptors is None:
        descriptors = np.zeros((num_features, 128))
    if len(descriptors) < num_features:
        descriptors = np.vstack([descriptors, np.zeros((num_features - len(descriptors), 128))])
    elif len(descriptors) > num_features:
        descriptors = descriptors[:num_features]
    return descriptors.flatten()

# Apply feature extraction to all images
features_hist = np.array([calc_histogram(img) for img in images])
features_canny = np.array([canny_edge_detection(img) for img in images])
features_sift = np.array([sift_features(img) for img in images])

print(f"Histogram features shape: {features_hist.shape}")
print(f"Canny edge features shape: {features_canny.shape}")
print(f"SIFT features shape: {features_sift.shape}")
# Out:
# Histogram features shape: (5245, 256)
# Canny edge features shape: (5245, 16384)
# SIFT features shape: (5245, 16384)

# %% [markdown]
# # Dimensionality Reduction
# Apply dimensionality reduction techniques if the feature set size is too large.
#
# # Classification Algorithm
# Choose and implement a classification algorithm.
#
# # Evaluation Components
# Evaluate the trained models using appropriate metrics.

# %%
# Function to apply PCA
def apply_pca(features, n_components=50):
    pca = PCA(n_components=n_components)
    reduced_features = pca.fit_transform(features)
    return pca, reduced_features

# Apply PCA
pca_hist, features_hist_pca = apply_pca(features_hist, n_components=50)
pca_canny, features_canny_pca = apply_pca(features_canny, n_components=50)
pca_sift, features_sift_pca = apply_pca(features_sift, n_components=50)

# Save PCA transformers
with open('pca_transformer_hist.pkl', 'wb') as pca_file:
    pickle.dump(pca_hist, pca_file)

with open('pca_transformer_canny.pkl', 'wb') as pca_file:
    pickle.dump(pca_canny, pca_file)

with open('pca_transformer_sift.pkl', 'wb') as pca_file:
    pickle.dump(pca_sift, pca_file)

# Combine PCA features for SVM training
combined_features = np.hstack((features_hist_pca, features_canny_pca, features_sift_pca))

# Split data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(combined_features, labels, test_size=0.2, random_state=42)

# Train the SVM classifier
classifier = SVC()
classifier.fit(X_train, y_train)

# Predict and evaluate
y_pred = classifier.predict(X_test)
print(classification_report(y_test, y_pred))
print("Accuracy:", accuracy_score(y_test, y_pred))

# Save the trained model
with open('svm_algo_model.pkl', 'wb') as model_file:
    pickle.dump(classifier, model_file)
# Out:
#               precision    recall  f1-score   support
#
#     Building       0.56      0.39      0.46       112
#       Forest       0.87      0.96      0.92       539
#      Glacier       0.47      0.52      0.49        94
#    Mountains       0.57      0.48      0.52       107
#          Sea       0.47      0.49      0.48        91
#      Streets       0.69      0.57      0.62       106
#
#     accuracy                           0.73      1049
#    macro avg       0.60      0.57      0.58      1049
# weighted avg       0.72      0.73      0.72      1049
#
# Accuracy: 0.7311725452812202
